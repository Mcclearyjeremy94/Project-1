# %% [markdown]
# <a href="https://colab.research.google.com/github/Mcclearyjeremy94/Project-1/blob/main/Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
path1= '/content/drive/MyDrive/healthcare-dataset-stroke-data.csv'
df1= pd.read_csv(path1)
df1.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %% [markdown]
# 1. This is healthcare data from kaggle
# 2. This is data that showing other health statistics and the risk of stroke
# 3. The target is to figure out if they did or did not have a stroke based on other health issues
# 4. The smoking status is a row that determines if they are a smoker or not
# 5. This is a classifcation problem
# 6. There are 10 features in the data set with the 11th being the target
# 7. threre are 5510 rows in this dataset
# 8. I do see there are a lot of missing values in the BMI so that might become an issue

# %% [markdown]
# #metabolic syndrome Data set 2

# %%
path='/content/drive/MyDrive/Metabolic  Syndrome.csv'
df= pd.read_csv(path)
df.head()
# Out:
#     seqn  Age     Sex  Marital  Income   Race  WaistCirc   BMI  Albuminuria  \
# 0  62161   22    Male   Single  8200.0  White       81.0  23.3            0
# 1  62164   44  Female  Married  4500.0  White       80.1  23.2            0
# 2  62169   21    Male   Single   800.0  Asian       69.6  20.1            0
# 3  62172   43  Female   Single  2000.0  Black      120.4  33.3            0
# 4  62177   51    Male  Married     NaN  Asian       81.1  20.1            0
#
#    UrAlbCr  UricAcid  BloodGlucose  HDL  Triglycerides MetabolicSyndrome
# 0     3.88       4.9            92   41             84         No MetSyn
# 1     8.55       4.5            82   28             56         No MetSyn
# 2     5.07       5.4           107   43             78         No MetSyn
# 3     5.22       5.0           104   73            141         No MetSyn
# 4     8.13       5.0            95   43            126         No MetSyn

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2401 entries, 0 to 2400
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   seqn               2401 non-null   int64
#  1   Age                2401 non-null   int64
#  2   Sex                2401 non-null   object
#  3   Marital            2193 non-null   object
#  4   Income             2284 non-null   float64
#  5   Race               2401 non-null   object
#  6   WaistCirc          2316 non-null   float64
#  7   BMI                2375 non-null   float64
#  8   Albuminuria        2401 non-null   int64
#  9   UrAlbCr            2401 non-null   float64
#  10  UricAcid           2401 non-null   float64
#  11  BloodGlucose       2401 non-null   int64
#  12  HDL                2401 non-null   int64
#  13  Triglycerides      2401 non-null   int64
#  14  MetabolicSyndrome  2401 non-null   object
# dtypes: float64(5), int64(6), object(4)
# ...

# %%
df['MetabolicSyndrome'].value_counts()
# Out:
# No MetSyn    1579
# MetSyn        822
# Name: MetabolicSyndrome, dtype: int64

# %% [markdown]
# 1. This is a data set from kaggle about metabolic syndrome
# 2. This data takes other health statistics to determine if someone has a metabolic syndrome or not
# 3. The target is to determine if the person has a metabolic syndrome or not
# 4. The income row determines what the persons monthly income is
# 5. This is a classifcation problem
# 6. This data set has 13 features with the 14th being the target
# 7. There are 2401 rows in this dataset
# 8. I see a problem since there are multiple columns that have missing data and may not really be apart of the end target
